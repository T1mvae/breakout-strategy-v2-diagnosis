# %% [markdown]
# # V2 Regime Filter Research
#
# Starter notebook for regime-filter research. Run `research/dataset_preparation/build_15m_dataset.py` first to generate the 15-minute dataset.

# %%
import pandas as pd
from pathlib import Path

# Load 15-minute dataset
PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / "data").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
DATA_PATH = PROJECT_ROOT / "data" / "processed" / "btc_15m.csv"
df = pd.read_csv(DATA_PATH)
df["open_time"] = pd.to_datetime(df["open_time"])
df = df.set_index("open_time")
print(f"Loaded {len(df)} rows")
print(df.head())

# %%
# Quick inspection
print(df.info())
print("\nDate range:", df.index.min(), "to", df.index.max())

# %% [markdown]
# ## Placeholder: Regime Filter Research
#
# See **research/regime_filter/ema_regime_filter_research.ipynb** for the full EMA regime filter evaluation:
# - EMA regime classification (trend_up / trend_down / range)
# - Hyperparameter sweep: ema_period ∈ [100, 150, 200, 250, 300]
# - Walk-forward evaluation (train / validation / OOS)
# - Baseline vs EMA filter comparison
